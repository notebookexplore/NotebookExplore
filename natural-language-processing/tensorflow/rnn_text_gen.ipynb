# %% [markdown]
# <table class="tfo-notebook-buttons" align="center">
#   <td>
#     <a
#       target="_blank"
#       href="https://colab.research.google.com/github/notebookexplore/notebookexplore/blob/master/natural-language-processing/tensorflow/rnn_text_gen.ipynb"
#       ><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run
#       in Google Colab</a
#     >
#   </td>
#   <td>
#     <a
#       target="_blank"
#       href="https://github.com/notebookexplore/notebookexplore/blob/master/natural-language-processing/tensorflow/rnn_text_gen.ipynb.ipynb"
#       ><img
#         src="https://www.tensorflow.org/images/GitHub-Mark-32px.png"
#       />View source on GitHub</a
#     >
#   </td>
# </table>

# %% [markdown]
# #  Interactive textgenrnn Demo w/ GPU
#
# by [Max Woolf](http://minimaxir.com)
#
# *Last updated: December 2nd, 2018*
#
# Generate text using a pretrained neural network with a few lines of code, or easily train your own text-generating neural network of any size and complexity, **for free on a GPU using Collaboratory!**
#
# For more about textgenrnn, you can visit [this GitHub repository](https://github.com/minimaxir/textgenrnn).
#
#
# To get started:
#
# 1. Copy this notebook to your Google Drive to keep it and save your changes.
# 2. Make sure you're running the notebook in Google Chrome.
# 3. Run the cells below:

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Set the textgenrnn model configuration here: the default parameters here give good results for most workflows. (see the [demo notebook](https://github.com/minimaxir/textgenrnn/blob/master/docs/textgenrnn-demo.ipynb) for more information about these parameters)
#
# If you are using an input file where documents are line-delimited, make sure to set `line_delimited` to `True`.

# %%
model_cfg = {
    'word_level': False,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 3,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 30,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 10000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 20,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = "tinyshakespeare.txt"
model_name = 'colaboratory'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Training new model w/ 3-layer, 128-cell LSTMs
# Training on 892,331 character sequences.
# Epoch 1/20
# 871/871 [==============================] - 112s 129ms/step - loss: 3.3335
# Epoch 2/20
# 871/871 [==============================] - 114s 131ms/step - loss: 2.2192
# Epoch 3/20
# 871/871 [==============================] - 110s 126ms/step - loss: 1.5837
# Epoch 4/20
# 871/871 [==============================] - 112s 128ms/step - loss: 1.4491
# Epoch 5/20
# 871/871 [==============================] - 109s 125ms/step - loss: 1.3801
# ####################
# Temperature: 0.2
# ####################
#  of the world shall be the sea,
# That who should not the state of the state,
# That have the strange of the state of the world serves to stay the state of this that we will not be the world of the law of the sea,
# That with his father shall be the county of this sin,
# The prover to be a subjects of the s
#
# father,
# That the strange of the world of the world of the state,
# That when the state of his strange,
# That have my son, and there in the state,
# That we have store the strange of the fair of the wars,
# And there the city of the county should see thee,
# That who should she will be the father of the wise
#
# the gods and the son,
# And therefore have the life of the case of the life,
# That should she will be the fire of the world soul the conscience of the father,
# Who doth thou dost stay to see the world of the county have straight for the world of the world soul they should not for the case,
# And therefore
#
# ####################
# Temperature: 0.5
# ####################
# e beast,
# Which they would they are never of this strange.
#
# DUKE VINCENTIO:
# The common that have pardon in the sea,
# To think your place in the sea had not stay for a man with your foolish,
# And down the world stand in the life,
# And since the will of the blood
# And to be a morning of this supper?
#
# CAPUL
#
# we canst thou art a first sword.
#
# ANTONIO:
# Well, was now she did make the lords.
#
# PETRUCHIO:
# What should she in his volist the gods of the season,
# Whom we will be a subject, and therefore, sole,
# There shall be a subject and case,
# And cannot have follower to me to store the fears,
# Thou shalt see thee
#
# re with a place is not too look
# And since with prove of his father's father.
#
# DUKE VINCENTIO:
# What was not all the sup sound the sea,
# What is the more of thy strange marriage.
#
# DUKE OF YORK:
# If the peace is so fortune to be praise me to the country shall be sour the manners of him.
#
# VOLUMNIA:
# Say, s
#
# ####################
# Temperature: 1.0
# ####################
# nd claims; since it,
# Be not a tormel with my king foul fatch:
# Therefore Euch ooney's mother speed,
# Assuerfied with our town kness foul blood.
#
# RATCLIFF:
# Well, cousin Warwick, speek in lafe make the rap of outwralf ladget in his druet to Most thee
# Thought he are doom'd flattering tail its need fore.
#
#
#  prutise
# More service me, and whose suffentst thou
# May dissole her elfer, at Lancaster
# Cabuld dear jest your weading:
# So how to make follower kissely! Dost ad though
# Banixene for us with this clave fade the maid?
#
# ABHORSON:
# An yet o'erwhell.
#
# DUKE VINCENTIO:
# Was's news in the provoster's loves;
# By I
#
# blood,
# And he has my setness, whom stoled o' the offence,
# But thou distalined and I lark, goodly love
# Our knee how out to thy hounce:
# With love that given your intairs:
# When is else.
#
# EDWARD:
# Whoined our fare authority root
# For you wilt stusp'd; For Warwick
# Of heaven have I rey in the juasing fears.
#
# Epoch 6/20
# 871/871 [==============================] - 110s 127ms/step - loss: 1.3342
# Epoch 7/20
# 871/871 [==============================] - 112s 129ms/step - loss: 1.3002
# Epoch 8/20
# 871/871 [==============================] - 109s 125ms/step - loss: 1.2721
# Epoch 9/20
# 871/871 [==============================] - 112s 128ms/step - loss: 1.2477
# Epoch 10/20
# 871/871 [==============================] - 114s 131ms/step - loss: 1.2257
# ####################
# Temperature: 0.2
# ####################
# e of the seat,
# And the seat of the seat of the holy man of the state of the seat of the world be so for the sun.
#
# GRUMIO:
# I would the sun single stones and the seat,
# And the store of the sin of my head of the world be proud to stay.
#
# BUCKINGHAM:
# What says you will not be a power of the more of the s
#
# ry sound of the world he was the desire of the man of my head.
#
# LEONTES:
# What is the matter?
#
# COMINIUS:
# So much is not worthy man to the world before the rest that hath been the seat, and the world doth be the world to the fortune with the seat,
# And bear the story was a man to be a man to be a power
#
# head is all the seat,
# And with the seat of the state of the seat,
# And the world will be so for the seat,
# And the store of the seat of the constable death.
#
# LUCIO:
# I was born to the duke of mine own brother with the world be so fair a man to do the court.
#
# LUCIO:
# I would the king is the world be the
#
# ####################
# Temperature: 0.5
# ####################
#  the daughter?
#
# BRUTUS:
# Away with him?
#
# BUCKINGHAM:
# My dear man have with my life and good thence.
#
# GRUMIO:
# I do not end our swords to rest as the boy
# And the merch of the seat that you read and come to breath and flught.
#
# LEONTES:
# It doth have force.
#
# LUCIO:
# I was between to make you the world for
#
# grief and the time.
#
# GLOUCESTER:
# Not of your grace to the cause of the state of my soldiers.
#
# LEONTES:
# And so thou hast hang'd me that is the world but a man the seat of my body.
#
# GLOUCESTER:
# I do beat my bastard!
#
# POMPEY:
# O, we were a fortune cause to stay.
#
# DUKE OF YORK:
# The world hath forgives no
#
# where thou canst meet her brother.
#
# CLIFFORD:
# Not a good arm of heaven, and the seat brief of such as it is the brother.
#
# DUKE VINCENTIO:
# I will not give a service and your fortunes.
#
# MENENIUS:
# He doth be my death,
# I have not the murderer doth down,
# To hold my land princely to his own brother than t
#
# ####################
# Temperature: 1.0
# ####################
# mark't the world; rides it yet;
# By govern'd grief man files thy painted soldiers
# catisport he was being submiright
# with the child; enmortain even mona-ladge.
# Come to, good Princes, in the lord o' the
# sorrow long beggar against his babe,
# Thus save the breathy cause weak'd makes Tybalt grief, speak as
#
# KE:
# Nor I, after hate: let her old King Richard's time to make
# your kindred state and a doubt with gnaterate opinion.
# Come home. Thou art, princely my good name
# Of disease. Change blessed his bed shortly redeng.
#
# HASTINGS:
# Let's best lace?
#
# Second Reman:
# Thath once as you wert a state.
#
# VOUMINGHAM:
#
#
# BOLINGBROKE:
# He'll realing her wounds I am age,
# Her words aloom, you did dance lute
# His bastard slay us death. If my matter you make your honours?
# A injuruly bosom!
#
# ANTONIO:
# The highness would give you for this ghostly brother: urest my deep dear lies,
# And have am I stood to-morrow have
# But their f
#
# Epoch 11/20
# 871/871 [==============================] - 112s 129ms/step - loss: 1.2048
# Epoch 12/20
# 871/871 [==============================] - 114s 131ms/step - loss: 1.1848
# Epoch 13/20
# 871/871 [==============================] - 116s 133ms/step - loss: 1.1659
# Epoch 14/20
# 871/871 [==============================] - 118s 135ms/step - loss: 1.1472
# Epoch 15/20
# 871/871 [==============================] - 116s 133ms/step - loss: 1.1290
# ####################
# Temperature: 0.2
# ####################
# e prince,
# And therefore have not the best.
#
# BAPTISTA:
# What is the matter?
#
# BAPTISTA:
# What is the matter?
#
# CORIOLANUS:
# I will be gone.
#
# LEONTES:
# The shame of the sea with me to the prince,
# That thou shalt be too report there was to do thee to the court.
#
# BUCKINGHAM:
# The man is no more than the way
# Th
#
# life of thee that was the deep desert.
#
# BUCKINGHAM:
# What is the matter?
#
# CORIOLANUS:
# I will not be so?
#
# SICINIUS:
# He will not be so?
#
# SEBASTIAN:
# And then I will be any of me to the court.
#
# BUCKINGHAM:
# What is the matter?
#
# MENENIUS:
# Now, by my countenance,
# I do be seen to do it.
#
# LUCENTIO:
# I will not
#
# e of the world,
# And then the state of the war and service
# Than the sea of the sea with the prince
# To see the time to make the walls,
# And therefore they are to the heavens
# Of the sea which shall be so far
# And then to the best of the prince,
# And then the presence of the best.
#
# BENVOLIO:
# The senators o
#
# ####################
# Temperature: 0.5
# ####################
# s woes to her heart,
# The pleasure and most rather to the bloody,
# And the captain that struck me royal feast.
#
# Second Murderer:
# How shall we promise your brother's sounders,
# The wall of our mother, the duke deserves me
# Before the murderer of the way to his country, let her be satisfied
# To make her li
#
#  shall be so bold
# Than the man that there prepared,
# And therefore have set me fair death,
# To stir the like and footed body,
# To make the sea of bear to fight.
#
# ISABELLA:
# And then, in the house of Gloucester,
# But the most sungererous world,
# And he shall have been the war whipp'd it was, so bear the su
#
# I do confess to the mind;
# Which now are the country's love of the pretty,
# The seal of thee that remove the sea, it is to do public to the father's speech,
# His subjects cannot be made, and there prove men be a ship brother.
#
# GLOUCESTER:
# A gentleman from the sun.
#
# CLARENCE:
# In the news is entertain'd
#
# ####################
# Temperature: 1.0
# ####################
# ithdraw
# What Katharina, begins the capt o' the
# sedilous dulsted, leannest and move think too death
# By yield and grief prodigiment,
# Leing lighteier things do perform them to be his counterfeit and shroud,
# Even to day of my ground. But what's thy note in nativeness,
# Whenst thou shalt be mer times.
#
# VO
#
#  a trange;
# The left you hit on fore, and, sitting and law,
# Nup tambing it in his characters, for the death-garmeness remains
# Am in earth, some me more, till thou wert an angel
# To be thisbs
# And they be no contented both; but struck our import.
# This is a kill'd on twenty things!
# Hath I beed fair fatal
#
#  pause to eat:
# But what you are bridges-man; though the
# sea divines: give time cliffer'd.
#
# BENVOLIO:
# When there's no law: must I have
# current sixthep was defended this delights are indeed,
# Did ever they say into the like of Sorrosio;--
# Come, then, as it is thieb aged.
#
# BALTHASAI:
# Fie, first, die, ha
#
# Epoch 16/20
# 871/871 [==============================] - 110s 127ms/step - loss: 1.1110
# Epoch 17/20
# 871/871 [==============================] - 112s 129ms/step - loss: 1.0934
# Epoch 18/20
# 871/871 [==============================] - 115s 133ms/step - loss: 1.0767
# Epoch 19/20
# 871/871 [==============================] - 115s 132ms/step - loss: 1.0607
# Epoch 20/20
# 871/871 [==============================] - 115s 132ms/step - loss: 1.0458
# ####################
# Temperature: 0.2
# ####################
# ison, that you have been so far o'er a shame,
# And with the sea to my father with him.
#
# KING RICHARD III:
# What say you that fall before the deputy
# To make a strange of the shadow of the sea,
# And therefore at the blood of the field,
# Who desires the sea with some princely fear
# To stand with the people,
#
# we may beat you this sentence of the king, and the heavens of the king,
# And with the prince of the poor great death.
#
# GLOUCESTER:
# I would thou wilt follow him.
#
# KING RICHARD II:
# What say you that live? I will not come to hear my state, and the prince be the watch is but a silken of the field,
# And so
#
# the fire,
# And therefore have not the fire,
# And with the better of the house of York
# The sea of the sea with a charge,
# And then the strange of the people,
# That thou shalt not see the sun.
#
# GLOUCESTER:
#
# KING EDWARD IV:
#
# BRAKENBURY:
# I have seen them all this sharp of the field,
# That we have spoke to th
#
# ####################
# Temperature: 0.5
# ####################
# ct
# To be so more patience. I have no contracted to bear
# The blood of this hour, the like death hath been made
# That thou mayst prove a man that have past'd by the self-arready in the sea of the feast.
#
# PETRUCHIO:
# I think you have no poor soul be the man.
#
# QUEEN MARGARET:
# Ay, this is mine own as it is
#
# ead that may have found me to make her dear bears;
# And this is well as the queen of his eye
# And seek the time that all the people,
# Which in the better of this father's body,
# That thou bears Salisbury; who should
# I can come to venge a man: and therefore then be proceeded of my soul,
# And with his grac
#
# y for the state,
# And then I think the whiles it should be hold.
#
# GLOUCESTER:
# Merely, that the tongue of mine,
# Should all the end of the stroke of the process
# Of such a weeder with the people is the world,
# And falls our sense is to do it.
#
# GLOUCESTER:
# Why, then it wouldst know the law
# Is like to the
#
# ####################
# Temperature: 1.0
# ####################
#  are but sadly. I know not the Duke of Norfolk,
# Which she more we will procure my love sword,
# When we may answer me blood; of letters--
# Hang all thee, my lord,--where are his own.
#
# First Servant:
# My lord, the garden horse, if they
# Will bring thee heinous: you are buried to
# Clarence hath find it with
#
# .
#
# BIONDELLO:
# I grant thy unkshows acress field, as he hath been no warrant goes
# In the eigner, and our trarch, tear.
#
# ESCALUS:
# Madam, 'tis nothing so?
#
# Gloomp
# Hasting, you shall prevent your less.
# If you not had thou see to command?
# And then, some mean me as--
#
# Second Gentle Lord!
#
# BUSHY:
# We know y
#
# th won in your affection else.
# So, that's a bisfort trage.
#
# DUKE VINCENTIO:
# It I have absolute that man imprison'blance
# As dislock upon this bugs in wife,
# Not brother make me make a gentleman.
#
# AUTOLYCUS:
# I come to the more plain sleep,
# My name was heresherd with a cheeks to chear out
# To traitor our

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download('{}_weights.hdf5'.format(model_name))
files.download('{}_vocab.json'.format(model_name))
files.download('{}_config.json'.format(model_name))

# %% [markdown]
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)

# %% [markdown]
# # Etcetera
#
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': '{}_weights.hdf5'.format(model_name)})
uploaded.SetContentFile('{}_weights.hdf5'.format(model_name))
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1b6T6M32YnXs-c0NB-PEi6MhAdCuG7RHy

# %% [markdown]
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
